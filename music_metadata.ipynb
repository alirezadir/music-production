# %%
from tinytag import TinyTag
import eyed3 
import pprint

tag = TinyTag.get('/Users/alirezadirafzoon/Baha_Awakening_(Michael_Brun_Mix).mp3')
print(tag.comment)

af = eyed3.load('/Users/alirezadirafzoon/Baha_Awakening_(Michael_Brun_Mix).mp3')
#TODO migrate to conda (install packs + update python path to conda's)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/z1/3zb9_s6j7vbb2f57prys5n0c0000gn/T/ipykernel_95597/2373383306.py in <module>
# ----> 1 from tinytag import TinyTag
#       2 import eyed3
#       3 import pprint
#       4
#       5 tag = TinyTag.get('/Users/alirezadirafzoon/Baha_Awakening_(Michael_Brun_Mix).mp3')
#
# ModuleNotFoundError: No module named 'tinytag'

# %%
import pprint
for k, v in dir(af.tag):
    print(k)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Untitled-1.ipynb Cell 2' in <cell line: 2>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000001untitled?line=0'>1</a> import pprint
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000001untitled?line=1'>2</a> for k, v in dir(af.tag):
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000001untitled?line=2'>3</a>     print(k)
#
# ValueError: too many values to unpack (expected 2)

# %%
af.tag
